# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
from random import *

# %%
data_train = pd.read_csv('./data/fashion-mnist_train.csv', header = 0)
data_train.head()
data_train.drop('label', axis = 1, inplace = True)
img = data_train.iloc[0].values.reshape(28, 28)
plt.imshow(img, cmap = 'gray')
